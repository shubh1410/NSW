# %%
import csv
import pandas as pd
from itertools import product
c=0
data_follower=pd.read_csv('/home/shuham/Desktop/Projects/NSW_Kashmir/#Kashmir_follower_followee_network.csv')
data_tweet= pd.read_csv('/home/shuham/Desktop/Projects/NSW_Kashmir/#Kashmir_tweets.csv')

# with open('/home/shuham/Desktop/ayodhyahearing_follower_network_new.csv') as f:
#     spamreader = csv.reader(f, delimiter=',')
# #     for k, m in [(t, s) for i, *j in spamreader for t, s in product(i, j)]:
# #         if len(m)!=0 :
# #             print (k, m)
# #             c=c+1
#     for row in spamreader:
#         for i in row:
#             if not m:
#                 print(row[0],i)

# %%
data_tweet.head()
# Out:
#                 user_id             status_id           created_at  \
# 0  x1167337853581348864  x1191968934087581696  2019-11-06 06:41:54
# 1             x38930724  x1191968880534675458  2019-11-06 06:41:41
# 2   x921238936726282240  x1191968708912173058  2019-11-06 06:41:00
# 3   x921238936726282240  x1191968520885669893  2019-11-06 06:40:15
# 4   x736161488591847424  x1191968706861158401  2019-11-06 06:41:00
#
#        screen_name                                               text  \
# 0           JKPNA1  First forceful occupation of #Kashmir and now ...
# 1       GoPeaceWay  Snowfall in #Kashmir #AJK 🍁https://t.co/KdL1lR...
# 2  AbdurRehman1918  مرے مالک مرے رہبر مدد کر \nکہ ہے کشمیر خوں سے ...
# 3  AbdurRehman1918  06 نومبر یوم شہدائے جموں\n\n#Kashmir #KashmirS...
# 4          MoFaisu  Snowfall in #Kashmir #AJK 🍁https://t.co/KdL1lR...
#
#                 source  display_text_width reply_to_status_id  \
# 0      Twitter Web App                 242                NaN
# 1  Twitter for Android                  66                NaN
# 2  Twitter for Android                 140                NaN
# 3  Twitter for Android                  78                NaN
# 4  Twitter for Android                  66                NaN
#
#   reply_to_user_id reply_to_screen_name  ...  statuses_count  \
# 0              NaN                  NaN  ...              34
# 1              NaN                  NaN  ...            2736
# 2              NaN                  NaN  ...            9570
# 3              NaN                  NaN  ...            9570
# 4              NaN                  NaN  ...            1297
#
#    favourites_count   account_created_at  verified              profile_url  \
# 0                19  2019-08-30 07:27:48     False  https://t.co/WF4UWYGfQj
# 1              5118  2009-05-09 21:22:58     False  https://t.co/RVmkiJX4xq
# 2             11385  2017-10-20 04:57:33     False                      NaN
# 3             11385  2017-10-20 04:57:33     False                      NaN
# 4              2924  2016-05-27 11:45:50     False                      NaN
#
#             profile_expanded_url account_lang  \
# 0  http://www.facebook.com/JKPNA          NaN
# 1        https://washington.org/          NaN
# 2                            NaN          NaN
# 3                            NaN          NaN
# 4                            NaN          NaN
#
#                                   profile_banner_url  \
# 0  https://pbs.twimg.com/profile_banners/11673378...
# 1  https://pbs.twimg.com/profile_banners/38930724...
# 2  https://pbs.twimg.com/profile_banners/92123893...
# 3  https://pbs.twimg.com/profile_banners/92123893...
# 4  https://pbs.twimg.com/profile_banners/73616148...
#
#                              profile_background_url  \
# 0                                               NaN
# 1  http://abs.twimg.com/images/themes/theme1/bg.png
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#                                    profile_image_url
# 0  http://pbs.twimg.com/profile_images/1167339524...
# 1  http://pbs.twimg.com/profile_images/1163535679...
# 2  http://pbs.twimg.com/profile_images/1184057184...
# 3  http://pbs.twimg.com/profile_images/1184057184...
# 4  http://pbs.twimg.com/profile_images/1177133745...
#
# [5 rows x 88 columns]

# %%
userid_screen_name= data_tweet[['user_id','screen_name']]
dict={}
# data3.iloc[0][0]
# data3.iloc[1][1]
c=len(userid_screen_name)
for i in range(c):
    dict[userid_screen_name.iloc[i][0][1:]]=userid_screen_name.iloc[i][1]
# for i in dict:
#     print(type(i))
dict
# Out:
# {'1014486577261654016': 'snow_man_14',
#  '834222548128768000': 'SuPrasAdmirer',
#  '1182526275493093376': 'AkkizSandip',
#  '4886815547': 'Russel_Olaf',
#  '100267062': 'KrazyKajolFan',
#  '2435437297': 'Rajaroysaha',
#  '805801485544001537': 'Rahul_akk',
#  '179911602': 'mysterioussu',
#  '4078877894': 'IndiaInd6',
#  '124517092': 'nekkantitsayz',
#  '258001976': 'thisisdharm',
#  '1144890050854834176': 'Taniya16310554',
#  '802147440': 'divya_badlani',
#  '2418649944': 'LifestyleByMona',
#  '1095222356316831744': 'GoldenJungBunny',
#  '1142063381232283650': 'Shailes01893067',
#  '740799913219502088': 'RahulWagh_007',
#  '449103305': 'akashiyr',
#  '1178971479364399105': 'EroticaWild',
#  '701743218082222080': 'SRKGlobe',
#  '124121096': 'ahmedabadmirror',
#  '777524340': 'FridayBrands',
#  '1175340015708246016': 'SDFilmyNews',
#  '1090642506767785985': 'SunilYa74656649',
#  '562809096': 'yourfan420',
#  '4629269598': 'vimalkmishra19',
#  '173064517': 'mvnair212',
#  '900668888622522368': 'AKSHAYsABHI',
#  '271808665': 'funnybunnyj',
#  '83341510': 'IndianYeti',
#  '1184308566234058752': 'RahulKu65351188',
#  '1136481620888702976': 'TeerthRajGarg1',
#  '120697956': 'Smiley_Bharati',
#  '713402666555219968': 'BeingPrem_',
#  '4243762032': 'Akshay_Brigade',
#  '928236845606957061': 'ContestFeeds',
#  '3212431358': 'SRKEGYPT_CFC',
#  '4523594062': 'gavvamedia',
#  '1176084199024910336': 'AnilDas33487738',
#  '841714394857906178': 'RekhaVyavhar',
#  '138781014': 'onenonlymahakal',
#  '2380524150': 'seemapeerzade97',
#  '994424019993559041': 'deeeeeva',
#  '1189788542458720257': 'BhadoriaChirag',
#  '321934848': 'SRKsAppleBoy',
#  '732625803083677696': 'ShaileshVk18',
#  '1145248057522446336': 'DJ_Bhayani',
#  '733716853223096321': 'OT7GurlwithLuv',
#  '1183244831084036098': 'Vaibhavkr2005',
#  '2152436336': 'jeherulislam19',
#  '117160956': 'ruchitweet',
#  '1443199994': 'chitrachainani',
#  '1896737190': 'spot_boyy',
#  '1706808024': 'Kushi_ku',
#  '3178038098': 'kanjain1995',
#  '1123818822228676608': 'chalbaechal',
#  '159831364': 'IamPrince167',
#  '261247247': 'VP3107',
#  '474874694': 'Princy_Aish',
#  '1936503824': 'ShirgaonkarAdil',
#  '926050254016872448': 'iam_Rohit97',
#  '752914050779054085': 'ACE_AAMIR_',
#  '2898449965': 'paidanchor',
#  '1194911942755926016': 'Bollywo75129142',
#  '953332363966087168': 'SRKKOLHAPURCFC',
#  '189074195': 'auk_sanejourno',
#  '3302207432': 'Hetalgalabjp',
#  '749088165252571136': 'Amesha__w',
#  '2186258666': 'Leo_Knock',
#  '749344925016166400': 'w3daily',
#  '711583037880967169': 'SNMHH_',
#  '66650221': 'DIVYASOLGAMA',
#  '1076147896569876480': 'SRKLUCKNOWCFC1',
#  '2896598653': 'princesofmd',
#  '3402668513': 'imvikas_A',
#  '865158775925346304': 'StefkaQneva1',
#  '3110432160': '91f8e3ba6b274e8',
#  '75634850': 'kbq4bjp',
#  '769567745931345920': 'jannaramazanov1',
#  '912974628917673985': 'iamVivekSRKian',
#  '2940495765': 'TaniaTannya118',
#  '735437409966428161': 'BollySpy',
#  '798492597656424448': 'montu13713',
#  '33523227': 'inscrutableviki',
#  '4054608313': 'beingsultan____',
#  '972881441506836480': 'vinodbansal_',
#  '4103985494': 'navaraajje',
#  '3144708542': 'Being_Saiyaara',
#  '1166602162455138304': 'Being_Rupes',
#  '99928370': 'Koimoi',
#  '977793691782918144': 'Shivangi3815',
#  '1007564446934470656': 'AlpeshP35056407',
#  '59394743': 'awzotp',
#  '2221866066': 'BJYM4Gujarat',
#  '2267274692': 'Sultan_nilesh',
#  '226061405': 'bollywood_life',
#  '1111974026199662593': 'news24upuk',
#  '824888088375676934': 'hoba64360400',
#  '1191028187586678787': 'Tarunmeena777',
#  '1196138031314391040': 'PradyumMizar',
#  '3317103829': 'farooquepathan3',
#  '1095178336609886210': 'Priyank80223499',
#  '17830429': 'sakaltimes',
#  '1085079607': 'Nishu_Kmr',
#  '918013896547434497': 'genitha6',
#  '1129786891404898304': 'RjuSharma1',
#  '1107229375328452612': 'SatishKumarBi14',
#  '845194852031643648': 'Adibairagi',
#  '754936080': 'bhartiyabhakt',
#  '1110794675986657280': 'Akshay59587477',
#  '1196311393500139520': 'ChugliBollywood',
#  '1163058613763493890': 'gujarati___',
#  '84313894': 'nassallu',
#  '916304520': 'Drnksingh16',
#  '971403215919988736': 'Sneeha_',
#  '354814219': 'AbhinavSaxena9',
#  '1010532728767381504': 'armznumbanine1',
#  '4617358399': 'atifjameel_aj',
#  '2772505729': 'HindiFilmibeat',
#  '927117023741583360': 'Sajed4SRK',
#  '500539736': 'satishkumaarrrr',
#  '281560798': 'SrkBastar',
#  '90125010': 'iDarshanBJP',
#  '468140492': 'minocchiato',
#  '1131862072071868416': 'MalaRoy16962322',
#  '4863308722': 'BeingSabrin',
#  '2445453458': 'aiyazahmed08',
#  '757107253115691009': 'FANwalagaurav',
#  '1107962885085368320': 'sitalovesindian',
#  '4330619121': 'RAJATVYAS137',
#  '132964544': 'neelikhan',
#  '2992453985': 'DelhiAkkians',
#  '1196366215247089664': 'Hifi12588726',
#  '554504255': 'Afilmmakerdream',
#  '854796493': 'Mr_Jhakassss',
#  '1189045570553483265': 'Spider_Gina',
#  '917695721444438016': 'bishrant11',
#  '1195123745620254720': 'ManaseeThakur',
#  '2974304162': 'TBReporter',
#  '914997542445711360': 'rajeshrawat0445',
#  '1184594743759519744': 'KabirAryan_91',
#  '795776745605500928': 'Kalakaaryan',
#  '94979487': 'pickooo',
#  '1188835026755940354': 'Abhik12857087',
#  '927890337254608896': 'fadiljfr',
#  '1105458767573934081': 'BOLLYWOODCOLLE2',
#  '950925650772213761': 'Aj__NaGesh',
#  '1169150189304778752': 'BrockMahi',
#  '1012372221355069440': 'southasiansnews',
#  '1116984110': 'JhaAmit91',
#  '1178898335366672385': 'AlbertM47951116',
#  '714041515': 'OverTheZayynBow',
#  '1045238042674384897': 'IwmbuzzHindi',
#  '879377240219303936': 'SahilSa35969096',
#  '601053458': 'JMatsima',
#  '134758540': 'timesofindia',
#  '1030054078099976192': 'iShri_AK',
#  '1037022253': 'abpsanjha',
#  '2722292352': 'FilmySansaar',
#  '1196370015773024257': 'tv_m19',
#  '106444549': 'samidsiddiqi91',
#  '175612701': '18AKGOYAL',
#  '1180397941309067264': 'Jyoti14300',
#  '18185256': 'OneindiaKannada',
#  '2769567750': 'FilmibeatKa',
#  '1056481652547870720': 'FANwalagaurav1',
#  '1077210066049069056': 'swagatnews',
#  '153693557': 'Ajay_Devgn_FC'}

# %%
len(dict)
# Out:
# 168

# %%
screen_followerId=data_follower[['screen_name','followerIDs']]
screen_followerId.head()
# Out:
#      screen_name                                        followerIDs
# 0    snow_man_14  1196063756578627585, 909322146492538881, 10775...
# 1  SuPrasAdmirer  1193434024410148865, 2796130205, 46332125, 339...
# 2    AkkizSandip  1194345674814320640, 1131775724736507904, 1193...
# 3    Russel_Olaf  1196012213062053888, 15556537, 108254727043074...
# 4  KrazyKajolFan  883508147842932740, 961199533165129728, 117684...

# %%
import math
followerId=screen_followerId['followerIDs']
list_follwerId=followerId.str.split(",")
names=screen_followerId['screen_name']
names[0]
list_follwerId
# Out:
# 0      [1196063756578627585,  909322146492538881,  10...
# 1      [1193434024410148865,  2796130205,  46332125, ...
# 2      [1194345674814320640,  1131775724736507904,  1...
# 3      [1196012213062053888,  15556537,  108254727043...
# 4      [883508147842932740,  961199533165129728,  117...
#                              ...
# 163                                               [none]
# 164    [1196431856582836224,  1196423501206310913,  1...
# 165    [1181774863737880576,  716514501642727424,  11...
# 166    [1196299892085448704,  1196216768169160709,  1...
# 167    [1196138031314391040,  872814843174281216,  11...
# Name: followerIDs, Length: 168, dtype: object

# %%
file1 = open("MyFile2.txt","a") 
c=0
counter=0
for item in list_follwerId:
    for i in item:
        if i in dict:
            #print(names[c],i)
            print(dict[i]+" "+i+" "+names[c])
            file1.write(""+dict[i]+" "+i+"\n")
            counter=counter+1
    c=c+1
# Out:
# spot_boyy 1896737190 iShri_AK
# PradyumMizar 1196138031314391040 Ajay_Devgn_FC

# %%
c
# Out:
# 168

# %%
counter
# Out:
# 2

# %%
c=0
for item in list_follwerId:
    for i in item:
        #print(names[c]+" "+i+"\n")
        if i in dict:
            print(i)
        #print(i)
    c=c+1
# Out:
# 1896737190
# 1196138031314391040

# %%
i='1181476077149052928'
if i in dict:
    print(i,dict[i])
# Out:
# 1181476077149052928 1Irshadkhan
